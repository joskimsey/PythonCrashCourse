# %%
def say_hi():
    print("hello user")

# %%
say_hi()
# Out:
# hello user

# %%
print("top")
# Out:
# top

# %%
print("bottom")
# Out:
# bottom

# %%
def say_hi(name,age):
    print("hello " + name + ",you are" + age)

# %%
say_hi("mike","35")
# Out:
# hello mike,you are35

# %%
say_hi("joseph", "19")
# Out:
# hello joseph,you are19
